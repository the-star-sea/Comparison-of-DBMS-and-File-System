# %%
import pandas as pd
import numpy as np
path1="G:/resources/数据库/pro1/release of project 1/data/course_info.json"
path2="G:/resources/数据库/pro1/release of project 1/data/select_course.csv"
cols_name = ['studentName','gender', 'college', 'studentId', 'course1', 'course2','course3','course4','course5','course6','course7']
course_info=pd.read_json(path1)
course_info[:60]
# Out:
#     totalCapacity courseId                                       prerequisite  \
# 0              28    GE232                                               None
# 1              30    GE232                                               None
# 2              30    GE232                                               None
# 3              30    GE232                                               None
# 4              28    GE232                                               None
# 5              30    GE232                                               None
# 6              28    GE232                                               None
# 7              28    GE232                                               None
# 8              28    GE232                                               None
# 9              28    GE232                                               None
# 10             30    GE232                                               None
# 11             30    GE232                                               None
# 12             30    GE232                                               None
# 13             28    GE232                                               None
# 14             28    GE232                                               None
# 15             30    GE232                                               None
# 16             30    GE232                                               None
# 17             30    GE232                                               None
# 18             30    GE232                                               None
# 19             30    GE232                                               None
# 20             30    GE232                                               None
# 21             30    GE232                                               None
# 22             30    GE232                                               None
# 23             30    GE232                                               None
# 24             30    GE232                                               None
# 25             30    GE232                                               None
# 26             30    GE232                                               None
# 27             30    GE232                                               None
# 28             28    GE232                                               None
# 29             30    GE232                                               None
# 30             30    GE232                                               None
# 31             28    GE232                                               None
# 32             30    GE232                                               None
# 33             30    GE232                                               None
# 34             20    EE332                             (数字电路 或者 数字电路 或者 数字电路)
# 35             20    EE332                             (数字电路 或者 数字电路 或者 数字电路)
# 36             90    CH215                                  (无机化学I 或者 无机化学导论)
# 37             50   BIO320                                   (普通生物学 或者 普通生物学)
# 38             50   BIO320                                   (普通生物学 或者 普通生物学)
# 39             50   ESE212  (化学原理 或者 化学原理 A 或者 化学原理 B) 并且 (大学物理A（下） 或者 大学物...
# 40             85  CH305-2                                             仪器分析原理
# 41             50    EE210                                               None
# 42             35    CS402                                               None
# 43             50    ME306                    (机械设计基础) 并且 (控制工程基础 或者 控制工程基础 )
# 44             20   ESE218                                                水力学
# 45            100    CH323                                             有机化学II
# 46             30   ESE216  (高等数学（下）A 或者 高等数学（下） 或者 数学分析II) 并且 (大学物理A(下) 或...
# 47             20   BIO340                                               None
# 48             50    ME303  (材料力学 或者 材料力学 或者 材料力学) 并且 (CAD与工程制图 或者 CAD技术Ⅱ)...
# 49             45    CS401  (计算机程序设计基础 或者 计算机编程基础 或者 计算机程序设计基础A) 并且 (数据结构与...
# 50             45    CS401  (计算机程序设计基础 或者 计算机编程基础 或者 计算机程序设计基础A) 并且 (数据结构与...
# 51             45    CS401  (计算机程序设计基础 或者 计算机编程基础 或者 计算机程序设计基础A) 并且 (数据结构与...
# 52             45    CS401  (计算机程序设计基础 或者 计算机编程基础 或者 计算机程序设计基础A) 并且 (数据结构与...
# 53             80   MSE202  (化学原理 或者 化学原理 A) 并且 (高等数学（下） 或者 高等数学（下）A 或者 数学...
# 54             50   MSE202  (化学原理 或者 化学原理 A) 并且 (高等数学（下） 或者 高等数学（下）A 或者 数学...
# 55             25   MED307                        (细胞生物学 并且 分子生物学 并且 组织学与胚胎学)
# 56             50    EE106                                               None
# 57             70   IPE105                                               None
# 58             70   IPE105                                               None
# 59             70   IPE105                                               None
#
#     courseHour  courseCredit       courseName                className  \
# 0           32           1.0             体育IV                    乒乓球3班
# 1           32           1.0             体育IV                    健美操2班
# 2           32           1.0             体育IV                     游泳1班
# 3           32           1.0             体育IV                   定向越野1班
# 4           32           1.0             体育IV                    羽毛球1班
# 5           32           1.0             体育IV                     散打2班
# 6           32           1.0             体育IV                    羽毛球2班
# 7           32           1.0             体育IV                    乒乓球1班
# 8           32           1.0             体育IV                     网球1班
# 9           32           1.0             体育IV                    羽毛球3班
# 10          32           1.0             体育IV                     棒球1班
# 11          32           1.0             体育IV                     搏击2班
# 12          32           1.0             体育IV                     健身1班
# 13          32           1.0             体育IV                    乒乓球2班
# 14          32           1.0             体育IV                     网球3班
# 15          32           1.0             体育IV                    健美操1班
# 16          32           1.0             体育IV                     排球1班
# 17          32           1.0             体育IV                     游泳3班
# 18          32           1.0             体育IV                     足球3班
# 19          32           1.0             体育IV                     健身2班
# 20          32           1.0             体育IV                     足球1班
# 21          32           1.0             体育IV                  运动和体能1班
# 22          32           1.0             体育IV                   体育舞蹈1班
# 23          32           1.0             体育IV                     排球2班
# 24          32           1.0             体育IV                     游泳4班
# 25          32           1.0             体育IV                    跆拳道1班
# 26          32           1.0             体育IV                     散打1班
# 27          32           1.0             体育IV                     足球2班
# 28          32           1.0             体育IV                     网球2班
# 29          32           1.0             体育IV                     游泳2班
# 30          32           1.0             体育IV                     篮球1班
# 31          32           1.0             体育IV                    羽毛球4班
# 32          32           1.0             体育IV                     轮滑1班
# 33          32           1.0             体育IV                     篮球2班
# 34          64           3.0           数字系统设计                     英文1班
# 35          64           3.0           数字系统设计                     英文2班
# 36          48           3.0             配位化学                      英文班
# 37          48           3.0            分子生物学                    中英双语班
# 38          48           3.0            分子生物学                      英文班
# 39          32           2.0             环境监测                    中英双语班
# 40          64           2.0           仪器分析实践  中英双语班（缺课不补课，缺课当次成绩记为0分）
# 41          48           3.0             光学基础                      英文班
# 42          16           1.0  计算机科学与技术前沿讲座 IV                      英文班
# 43          64           3.0            机器人基础                    中英双语班
# 44          16           0.5          水力学基础实验                      中文班
# 45          32           2.0          天然产物全合成                      中文班
# 46          48           3.0              水力学                      中文班
# 47          48           3.0            蛋白质工程                      英文班
# 48          48           3.0           机械设计基础                      英文班
# 49          64           3.0            智能机器人                 英文班-实验3班
# 50          64           3.0            智能机器人                 英文班-实验4班
# 51          64           3.0            智能机器人                 英文班-实验2班
# 52          64           3.0            智能机器人            英文班-实验1班（国际生）
# 53          48           3.0             物理化学           英文班（材料专业学生选此班）
# 54          48           3.0             物理化学          中英双语（环境专业同学选此班）
# 55          48           3.0              病理学                    中英双语班
# 56          32           2.0            光电子导论                    中英双语班
# 57          32           2.0            形势与政策                     中文1班
# 58          32           2.0            形势与政策                     中文9班
# 59          32           2.0            形势与政策                     中文7班
#
#      courseDept              teacher  \
# 0          体育中心                  何紫琳
# 1          体育中心                   赖莎
# 2          体育中心                  魏伟成
# 3          体育中心               体育外聘教师
# 4          体育中心               体育外聘教师
# 5          体育中心                   卢阳
# 6          体育中心                  赵一品
# 7          体育中心                  何紫琳
# 8          体育中心                   白波
# 9          体育中心                  魏伟成
# 10         体育中心               体育外聘教师
# 11         体育中心                   卢阳
# 12         体育中心                   赵飞
# 13         体育中心                  何紫琳
# 14         体育中心                   白波
# 15         体育中心                   赖莎
# 16         体育中心                  侯思宇
# 17         体育中心               体育外聘教师
# 18         体育中心                   孙颜
# 19         体育中心                   赵飞
# 20         体育中心                  赵一品
# 21         体育中心                  董伦红
# 22         体育中心                   赖莎
# 23         体育中心                  侯思宇
# 24         体育中心               体育外聘教师
# 25         体育中心               体育外聘教师
# 26         体育中心                   卢阳
# 27         体育中心                  赵一品
# 28         体育中心                   白波
# 29         体育中心                  魏伟成
# 30         体育中心                  侯思宇
# 31         体育中心               体育外聘教师
# 32         体育中心                   孙颜
# 33         体育中心                   赵飞
# 34     电子与电气工程系                  虞亚军
# 35     电子与电气工程系                  虞亚军
# 36          化学系                  黄文忠
# 37          生物系                  李瑞熙
# 38          生物系                   邓怿
# 39    环境科学与工程学院                  唐圆圆
# 40          化学系  朱秀珍,何绮婷,李晓华,汤小菊,王春燕
# 41     电子与电气工程系                  刘言军
# 42    计算机科学与工程系                \t刘烨庞
# 43     机械与能源工程系              柯文德,陈义明
# 44    环境科学与工程学院                  匡星星
# 45          化学系                   徐晶
# 46    环境科学与工程学院                  匡星星
# 47          生物系          Peter Pimpl
# 48     机械与能源工程系              王宏强,肖啸川
# 49    计算机科学与工程系                   郝祁
# 50    计算机科学与工程系                   郝祁
# 51    计算机科学与工程系                   郝祁
# 52    计算机科学与工程系                   郝祁
# 53     材料科学与工程系                  田雷蕾
# 54     材料科学与工程系                  唐圆圆
# 55          医学院                  张文勇
# 56     电子与电气工程系                   罗丹
# 57  思想政治教育与研究中心                  王德军
# 58  思想政治教育与研究中心                  杨晗旭
# 59  思想政治教育与研究中心                  王德军
#
#                                             classList
# 0   [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 1   [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 2   [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 3   [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 4   [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 5   [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 6   [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 7   [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 8   [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 9   [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 10  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 11  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 12  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 13  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 14  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 15  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 16  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 17  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 18  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 19  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 20  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 21  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 22  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 23  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 24  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 25  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 26  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 27  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 28  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 29  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 30  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 31  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 32  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 33  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 34  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 35  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 36  [{'weekList': ['2', '4', '6', '8', '10', '12',...
# 37  [{'weekList': ['1', '3', '5', '7', '9', '11', ...
# 38  [{'weekList': ['2', '4', '6', '8', '10', '12',...
# 39  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 40  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 41  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 42  [{'weekList': ['2', '4', '6', '8', '10', '12',...
# 43  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 44  [{'weekList': ['2', '4', '6', '8', '10', '12',...
# 45  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 46  [{'weekList': ['2', '4', '6', '8', '10', '12',...
# 47  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 48  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 49  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 50  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 51  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 52  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 53  [{'weekList': ['1', '3', '5', '7', '9', '11', ...
# 54  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 55  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 56  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 57  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 58  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 59  [{'weekList': ['1', '2', '3', '4', '5', '6', '...

# %%
course_info1=course_info
course_info1.columns
col1=['totalCapacity', 'courseId', 'courseHour',
       'courseCredit', 'courseName', 'className', 'courseDept', 'teacher',
       'classList']
course_info2=pd.DataFrame(columns=col1)
course_info2=course_info1[col1]
course_info2
# Out:
#      totalCapacity courseId  courseHour  courseCredit courseName className  \
# 0               28    GE232          32           1.0       体育IV     乒乓球3班
# 1               30    GE232          32           1.0       体育IV     健美操2班
# 2               30    GE232          32           1.0       体育IV      游泳1班
# 3               30    GE232          32           1.0       体育IV    定向越野1班
# 4               28    GE232          32           1.0       体育IV     羽毛球1班
# ..             ...      ...         ...           ...        ...       ...
# 592            150  PHY105B          64           4.0  大学物理 B(下)    中英双语6班
# 593            150  PHY105B          64           4.0  大学物理 B(下)    中英双语5班
# 594            150  PHY105B          64           4.0  大学物理 B(下)    中英双语4班
# 595            150  PHY105B          64           4.0  大学物理 B(下)    中英双语3班
# 596            150  PHY105B          64           4.0  大学物理 B(下)    中英双语2班
#
#     courseDept teacher                                          classList
# 0         体育中心     何紫琳  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 1         体育中心      赖莎  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 2         体育中心     魏伟成  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 3         体育中心  体育外聘教师  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 4         体育中心  体育外聘教师  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# ..         ...     ...                                                ...
# 592        物理系     吴健生  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 593        物理系     鲁大为  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 594        物理系     吴文政  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 595        物理系      刘畅  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
# 596        物理系     陈远珍  [{'weekList': ['1', '2', '3', '4', '5', '6', '...
#
# [597 rows x 9 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# G:\anaconda3\envs\te1\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('teacher', 'className')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-56bd4dd39bc9> in <module>
# ----> 1 teacher_dep=course_info1['teacher','className']
#
# G:\anaconda3\envs\te1\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# G:\anaconda3\envs\te1\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: ('teacher', 'className')
